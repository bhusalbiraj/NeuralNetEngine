# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
inputs = pd.read_csv("X.csv")
outputs = pd.read_csv("y.csv")

# %%
inputs.head()
# Out:
#    0.000000000000000000e+00  0.000000000000000000e+00.1
# 0                 -0.001282                    0.010019
# 1                  0.011518                    0.016597
# 2                  0.016787                    0.025229
# 3                  0.011275                    0.038799
# 4                  0.000595                    0.050502

# %%
inputs.columns = ["X", "y"]

# %%
inputs.head()
# Out:
#           X         y
# 0 -0.001282  0.010019
# 1  0.011518  0.016597
# 2  0.016787  0.025229
# 3  0.011275  0.038799
# 4  0.000595  0.050502

# %%
inputs.loc[len(inputs)] = [0.0000000, 0.0000000]

# %%
inputs.head()
# Out:
#           X         y
# 0 -0.001282  0.010019
# 1  0.011518  0.016597
# 2  0.016787  0.025229
# 3  0.011275  0.038799
# 4  0.000595  0.050502

# %%
outputs.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
outputs.columns=[["Outputs"]]

# %%
outputs.head()
# Out:
#   Outputs
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
outputs.loc[len(inputs)] = [0]

# %%
x = inputs['X'].to_numpy()

# %%
y = inputs['y'].to_numpy()

# %%
y
# Out:
# array([ 1.00193321e-02,  1.65970027e-02,  2.52285970e-02,  3.87990404e-02,
#         5.05015500e-02,  1.16527163e-02,  7.05370810e-02,  7.84105554e-02,
#         8.96083904e-02,  7.97429470e-02,  9.68373839e-02,  1.18162871e-01,
#         1.01036589e-01,  6.02554127e-02,  3.08912553e-03, -2.63580072e-02,
#        -1.20355980e-01, -4.85348716e-02,  4.93983237e-02, -2.84116918e-02,
#        -1.82759339e-01, -2.20811017e-01, -1.27248749e-01, -2.32647444e-01,
#        -2.50055392e-01, -2.61382916e-01, -2.61166344e-01, -2.81593542e-01,
#        -2.88734179e-01, -1.95707956e-01, -3.02576052e-01, -2.73246440e-01,
#        -2.89613665e-01, -2.02414496e-01, -2.61064218e-01, -3.34672978e-01,
#        -3.67567129e-01, -3.52928566e-01, -1.14396353e-01, -1.68919262e-01,
#        -3.86924524e-01,  1.76160274e-02, -4.22255651e-01,  1.58264753e-01,
#        -2.40878654e-01, -1.80072151e-01,  3.80087957e-02,  7.96852224e-02,
# ...

# %%
bigdata = pd.concat([inputs, outputs], axis =1)

# %%
bigdata.head()
# Out:
#           X         y  (Outputs,)
# 0 -0.001282  0.010019         0.0
# 1  0.011518  0.016597         0.0
# 2  0.016787  0.025229         0.0
# 3  0.011275  0.038799         0.0
# 4  0.000595  0.050502         0.0

# %%
bigdata.columns = ["X", "Y", "outputs"]

# %%
bigdata.tail()
# Out:
#             X         Y  outputs
# 296 -0.742993  0.638722      2.0
# 297 -0.960079 -0.241141      2.0
# 298 -0.978347 -0.206972      2.0
# 299  0.000000  0.000000      NaN
# 300       NaN       NaN      0.0

# %%
bigdata.dropna(inplace=True)

# %%
bigdata.isnull().sum()
# Out:
# X          0
# Y          0
# outputs    0
# dtype: int64

# %%
bigdata.tail()
data = bigdata

# %%
class0 = data[data["outputs"] == 0]
class1 = data[data["outputs"] == 1]
class2 = data[data["outputs"] == 2]
fig, ax = plt.subplots(figsize=(6,6), layout='constrained')

ax.scatter(class0["X"], class0["Y"], color="red")
ax.scatter(class1["X"], class1["Y"], color="green")
ax.scatter(class2["X"], class2["Y"], color="blue")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.legend()

plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_6788\1703843252.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
